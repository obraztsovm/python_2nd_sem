# %%
# !git remote set-url origin https://obraztsovm:ТОКЕН_БЫЛ_ЗДЕСЬ_9FJCaR8lbZ6kBs2W1MglEl6KBFLiV24ELTiM@github.com/obraztsovm/python_2nd_sem

# %%
# !git remote -v
# Out:
# origin	https://obraztsovm:ТОКЕН_БЫЛ_ЗДЕСЬ_9FJCaR8lbZ6kBs2W1MglEl6KBFLiV24ELTiM@github.com/obraztsovm/python_2nd_sem (fetch)
# origin	https://obraztsovm:ТОКЕН_БЫЛ_ЗДЕСЬ_9FJCaR8lbZ6kBs2W1MglEl6KBFLiV24ELTiM@github.com/obraztsovm/python_2nd_sem (push)

# %%
# !cd ../
# !ls -la
# Out:
# total 40204
# drwxr-xr-x 4 root root     4096 Mar 12 16:35 .
# drwxr-xr-x 1 root root     4096 Mar 12 16:35 ..
# drwxr-xr-x 8 root root     4096 Mar 12 16:42 .git
# drwxr-xr-x 2 root root     4096 Mar 12 16:35 lab1
# -rw-r--r-- 1 root root  9033957 Mar 12 16:35 olist_customers_dataset.csv
# -rw-r--r-- 1 root root 14451670 Mar 12 16:35 olist_order_reviews_dataset.csv
# -rw-r--r-- 1 root root 17654914 Mar 12 16:35 olist_orders_dataset.csv
# -rw-r--r-- 1 root root       47 Mar 12 16:35 README.md

# %%
cp /content/lab2.ipynb/python_2nd_sem/lab2.ipynb
# Out:
# cp: missing destination file operand after '/content/lab2.ipynb/python_2nd_sem/lab2.ipynb'
# Try 'cp --help' for more information.
